# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("IcebergAtividade") \
    .config("spark.jars.packages", "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.4.2") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.iceberg.spark.SparkSessionCatalog") \
    .config("spark.sql.catalog.spark_catalog.type", "hadoop") \
    .config("spark.sql.catalog.spark_catalog.warehouse", "/home/vinicius/trabalho-spark-engdados/warehouse") \
    .getOrCreate()

spark
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[1], line 10
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("IcebergAtividade") \
#       5     .config("spark.jars.packages", "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.4.2") \
#       6     .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
#       7     .config("spark.sql.catalog.spark_catalog", "org.apache.iceberg.spark.SparkSessionCatalog") \
#       8     .config("spark.sql.catalog.spark_catalog.type", "hadoop") \
#       9     .config("spark.sql.catalog.spark_catalog.warehouse", "/home/vinicius/trabalho-spark-engdados/warehouse") \
# ---> 10     .getOrCreate()
#      12 spark
#
# File c:\Users\jvol2\OneDrive\Área de Trabalho\EngDadosTrabalho\.venv\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\jvol2\OneDrive\Área de Trabalho\EngDadosTrabalho\.venv\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\jvol2\OneDrive\Área de Trabalho\EngDadosTrabalho\.venv\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\jvol2\OneDrive\Área de Trabalho\EngDadosTrabalho\.venv\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\jvol2\OneDrive\Área de Trabalho\EngDadosTrabalho\.venv\Lib\site-packages\pyspark\java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
df = spark.read.csv("/home/vinicius/trabalho-spark-engdados/data/vendas.csv", header=True, inferSchema=True)

# %%
spark.sql("""
CREATE TABLE vendas_iceberg (
    id INT,
    produto STRING,
    valor DOUBLE,
    quantidade INT,
    data STRING
)
USING iceberg
""")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 spark.sql("""
#       2 CREATE TABLE vendas_iceberg (
#       3     id INT,
#       4     produto STRING,
#       5     valor DOUBLE,
#       6     quantidade INT,
#       7     data STRING
#       8 )
#       9 USING iceberg
#      10 """)
#
# File ~/.cache/pypoetry/virtualenvs/trabalho-spark-engdados-6_wTpcsQ-py3.12/lib/python3.12/site-packages/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File ~/.cache/pypoetry/virtualenvs/trabalho-spark-engdados-6_wTpcsQ-py3.12/lib/python3.12/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/.cache/pypoetry/virtualenvs/trabalho-spark-engdados-6_wTpcsQ-py3.12/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [TABLE_OR_VIEW_ALREADY_EXISTS] Cannot create table or view `default`.`vendas_iceberg` because it already exists.
# Choose a different name, drop or replace the existing object, or add the IF NOT EXISTS clause to tolerate pre-existing objects.

# %%
spark.sql("""
INSERT INTO vendas_iceberg VALUES
(1000, 'Mouse', 80.0, 2, '2024-02-01'),
(1001, 'Teclado', 150.0, 1, '2024-02-01'),
(1002, 'Monitor', 900.0, 1, '2024-02-02'),
(1003, 'Notebook', 3500.0, 1, '2024-02-03'),
(1004, 'Headset', 120.0, 3, '2024-02-03')
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
UPDATE vendas_iceberg
SET valor = 90
WHERE id = 1000
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
DELETE FROM vendas_iceberg
WHERE id = 1000
""")
# Out:
# DataFrame[]

# %%
spark.sql("SELECT * FROM vendas_iceberg").show()
# Out:
# +----+--------+------+----------+----------+
# |  id| produto| valor|quantidade|      data|
# +----+--------+------+----------+----------+
# |1000|   Mouse|  80.0|         2|2024-02-01|
# |1001| Teclado| 150.0|         1|2024-02-01|
# |1002| Monitor| 900.0|         1|2024-02-02|
# |1003|Notebook|3500.0|         1|2024-02-03|
# |1004| Headset| 120.0|         3|2024-02-03|
# +----+--------+------+----------+----------+
